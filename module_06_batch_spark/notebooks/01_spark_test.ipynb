# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark.conf import SparkConf
from pyspark.context import SparkContext

# 1. Path to the JAR we downloaded with gsutil
# 2. Path to the JSON Key we just moved to credentials/
credentials_location = '/home/moha_/.google/credentials/google_credentials.json'

conf = SparkConf() \
    .setMaster('local[*]') \
    .setAppName('GCS_Mastery') \
    .set("spark.jars", "./lib/gcs-connector-hadoop3-latest.jar") \
    .set("spark.hadoop.google.cloud.auth.service.account.enable", "true") \
    .set("spark.hadoop.google.cloud.auth.service.account.json.keyfile", credentials_location)

# Create the Session
spark = SparkSession.builder \
    .config(conf=conf) \
    .getOrCreate()

# 3. The "Cloud Bridge" Configuration
# This tells Spark how to handle the 'gs://' address prefix
hadoop_conf = spark._jsc.hadoopConfiguration()
hadoop_conf.set("fs.AbstractFileSystem.gs.impl",  "com.google.cloud.hadoop.fs.gcs.GoogleHadoopFS")
hadoop_conf.set("fs.gs.impl", "com.google.cloud.hadoop.fs.gcs.GoogleHadoopFileSystem")
hadoop_conf.set("fs.gs.auth.service.account.enable", "true")
hadoop_conf.set("fs.gs.auth.service.account.json.keyfile", credentials_location)

print("🚀 Spark is officially connected to Google Cloud!")
# Out:
# 26/03/04 02:09:28 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/03/04 02:09:28 WARN DependencyUtils: Local jar /home/moha_/projects/dataeng/module_06_batch_spark/notebooks/lib/gcs-connector-hadoop3-latest.jar does not exist, skipping.
# 26/03/04 02:09:28 INFO SparkContext: Running Spark version 3.5.0
# 26/03/04 02:09:28 INFO SparkContext: OS info Linux, 6.6.87.2-microsoft-standard-WSL2, amd64
# 26/03/04 02:09:28 INFO SparkContext: Java version 11.0.30
# 26/03/04 02:09:28 INFO ResourceUtils: ==============================================================
# 26/03/04 02:09:28 INFO ResourceUtils: No custom resources configured for spark.driver.
# 26/03/04 02:09:28 INFO ResourceUtils: ==============================================================
# 26/03/04 02:09:28 INFO SparkContext: Submitted application: GCS_Mastery
# ...
