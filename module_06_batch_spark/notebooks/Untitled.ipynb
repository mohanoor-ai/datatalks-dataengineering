# %%
# This prints the active Web UI link for your specific session
print(f"Click here to see your Spark Jobs: {spark.sparkContext.uiWebUrl}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # This prints the active Web UI link for your specific session
# ----> 2 print(f"Click here to see your Spark Jobs: {spark.sparkContext.uiWebUrl}")
#
# NameError: name 'spark' is not defined
